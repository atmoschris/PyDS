# %%
import pyds as pd

# %%
x, y, z = pd.Model.Lorenz63(nt=6000, prt=False)
# Out:
# >>>>>> Lorenz63 ...
#
#        sigma: 10
#            r: 28
#            b: 2.6666666666666665
# (x0, y0, z0): (0, 1, 0)
#           dt: 0.01
#           nt: 6000
#   int_method: double-approx
#
# ...................

# %%
x1, y1, z1 = pd.Model.Lorenz63(int_method='RK4', nt=6000, prt=False)
# Out:
# >>>>>> Lorenz63 ...
#
#        sigma: 10
#            r: 28
#            b: 2.6666666666666665
# (x0, y0, z0): (0, 1, 0)
#           dt: 0.01
#           nt: 6000
#   int_method: RK4
#
# ...................

# %%
# %matplotlib inline

# %%
pd.Plot.trajectory_1d(y[0:1000])

# %%
pd.Plot.trajectory_1d(y1[0:1000])

# %%
pd.Plot.trajectory_1d(y[0:1000]-y1[0:1000])

# %%
pd.Plot.trajectory_1d(y[1000:2000])

# %%
pd.Plot.trajectory_1d(y1[1000:2000])

# %%
pd.Plot.trajectory_1d(y[1000:2000]-y1[1000:2000])

# %%
pd.Plot.trajectory_1d(y[2000:3000])

# %%
pd.Plot.trajectory_1d(y1[2000:3000])

# %%
pd.Plot.trajectory_1d(y[2000:3000]-y1[2000:3000])

# %%
pd.Plot.trajectory_2d(y[1400:1900], z[1400:1900])

# %%
pd.Plot.trajectory_2d(y1[1400:1900], z1[1400:1900])

# %%
pd.Plot.trajectory_2d(y[1400:1900], -x[1400:1900])

# %%
pd.Plot.trajectory_2d(y1[1400:1900], -x1[1400:1900])

# %%
pd.Plot.trajectory_3d(x, y, z, animation=False)

# %%
pd.Plot.trajectory_3d(x1, y1, z1, animation=False)
